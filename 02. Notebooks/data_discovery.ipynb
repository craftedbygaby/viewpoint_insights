# %% [markdown]
# # 01 Importing basic libraries

# %%
import os
import math
import random
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import scipy
import numpy as np
import pandas as pd
import scipy.stats as st

# %% [markdown]
# # 02. Importing initial data for checking

# %%
# Turismo.gov.br - Ministério do Turismo
arrivals_2015 = pd.read_csv('../01. Data/01. Raw Data/Turismo.gov/chegadas_2015.csv', encoding='latin-1', sep=';')
arrivals_2016 = pd.read_csv('../01. Data/01. Raw Data/Turismo.gov/chegadas_2016.csv', encoding='latin-1', sep=';')
arrivals_2017 = pd.read_csv('../01. Data/01. Raw Data/Turismo.gov/chegadas_2017.csv', encoding='latin-1', sep=';')
arrivals_2018 = pd.read_csv('../01. Data/01. Raw Data/Turismo.gov/chegadas_2018.csv', encoding='latin-1', sep=';')
arrivals_2019 = pd.read_csv('../01. Data/01. Raw Data/Turismo.gov/chegadas_2019.csv', encoding='latin-1', sep=';')
arrivals_2020 = pd.read_csv('../01. Data/01. Raw Data/Turismo.gov/chegadas_2020.csv', encoding='latin-1', sep=';')
arrivals_2021 = pd.read_csv('../01. Data/01. Raw Data/Turismo.gov/chegadas_2021.csv', encoding='latin-1', sep=';')
arrivals_2022 = pd.read_csv('../01. Data/01. Raw Data/Turismo.gov/chegadas_2022.csv', encoding='latin-1', sep=';')
arrivals_2023 = pd.read_csv('../01. Data/01. Raw Data/Turismo.gov/chegadas_2023.csv', encoding='latin-1', sep=';') 
arrivals_2024 = pd.read_csv('../01. Data/01. Raw Data/Turismo.gov/chegadas_2024.csv', encoding='latin-1', sep=';')

# %%
# Our World in Data
international_tourism = pd.read_csv('../01. Data/01. Raw Data/Our_World_in_Data/international-tourist-trips.csv')

# %%
# UnTourism - UNWTO
international_tourism_un = pd.read_excel('../01. Data/01. Raw Data/UNWTO/02_Inbound/01_Total_arrivals/UN_Tourism_inbound_arrivals_12_2025.xlsx', sheet_name='Data')

# %% [markdown]
# # 03.1 Discovery and data understanding - Turismo.gov

# %%
arrivals_2015.shape, arrivals_2016.shape, arrivals_2017.shape, arrivals_2018.shape, arrivals_2019.shape, arrivals_2020.shape, arrivals_2021.shape, arrivals_2022.shape, arrivals_2023.shape, arrivals_2024.shape
# Out:
# ((46872, 12),
#  (44640, 12),
#  (43524, 12),
#  (46872, 12),
#  (49104, 12),
#  (47988, 12),
#  (55800, 12),
#  (54684, 12),
#  (34764, 12),
#  (22856, 12))

# %%
# checking columns names and data structure
arrivals_2015.head()
# Out:
#   Continente  Ordem continente           País  Ordem país    UF  Ordem UF  \
# 0     África                 1  África do Sul           2  Acre         1
# 1     África                 1         Angola           6  Acre         1
# 2     África                 1     Cabo Verde          35  Acre         1
# 3     África                 1          Egito          60  Acre         1
# 4     África                 1           Gana          77  Acre         1
#
#   Via de acesso  Ordem via de acesso   ano      Mês  Ordem mês  Chegadas
# 0     Terrestre                    2  2015  janeiro          1         2
# 1     Terrestre                    2  2015  janeiro          1         0
# 2     Terrestre                    2  2015  janeiro          1         0
# 3     Terrestre                    2  2015  janeiro          1         0
# 4     Terrestre                    2  2015  janeiro          1         0

# %%
# checking columns names and data structure
arrivals_2016.head()
# Out:
#   Continente  cod continente           País  cod pais    UF  cod uf  \
# 0     África               1  África do Sul         2  Acre       1
# 1     África               1         Angola         6  Acre       1
# 2     África               1     Cabo Verde        35  Acre       1
# 1        1  2021  fevereiro        2         0
# 2        1  2021      março        3         0
# 3        1  2021      abril        4         0
# 4        1  2021       maio        5         0

# %%
# checking columns names and data structure
arrivals_2022.head()
# Out:
#   Continente  cod continente           País  cod pais    UF  cod uf    Via  \
# 0     África               1  África do Sul         2  Acre       1  Aérea
# 1     África               1  África do Sul         2  Acre       1  Aérea
# 2     África               1  África do Sul         2  Acre       1  Aérea
# 3     África               1  África do Sul         2  Acre       1  Aérea
# 4     África               1  África do Sul         2  Acre       1  Aérea
#
#    cod via   ano        Mês  cod mes  Chegadas
# 0        1  2022    Janeiro        1         0
# 1        1  2022  Fevereiro        2         0
# 2        1  2022      março        3         0
# 3        1  2022      Abril        4         0
# 4        1  2022       Maio        5         0

# %%
# checking columns names and data structure
arrivals_2023.head()
# Out:
#        Continente  cod continente           País  cod pais  \
# 0  América do Sul               4           Peru        34
# 1  América do Sul               4           Peru        34
# 2            Ásia               5  Outros países        56
# 3          Europa               6       Alemanha        57
# 4          Europa               6       Alemanha        57
#
#                              UF  cod uf    Via  cod via   ano        Mês  \
# 0                          Acre       1  Aéreo        1  2023   Novembro
# 1                          Acre       1  Aéreo        1  2023   Novembro
# 2  Outras Unidades da Federação      99  Aéreo        1  2023      Junho
# 3  Outras Unidades da Federação      99  Aéreo        1  2023    Janeiro
# 4  Outras Unidades da Federação      99  Aéreo        1  2023  Fevereiro
#
#    cod mes  Chegadas
# 0       11         0
# 1       11         0
# 2        6         0
# 3        1        12
# 4        2        10

# %%
# checking columns names and data structure
arrivals_2024.head()
# Out:
#          Continente  cod continente       País  cod pais  \
# 0            Europa               6   Alemanha        57
# 1    América do Sul               4  Argentina        26
# 2            Europa               6    Bélgica        59
# 3  América do Norte               3     Canadá        23
# 4    América do Sul               4      Chile        28
#
#                              UF  cod uf    Via  cod via   ano      Mês  \
# 0  Outras Unidades da Federação      99  Aérea        1  2024  Janeiro
# 1  Outras Unidades da Federação      99  Aérea        1  2024  Janeiro
# 2  Outras Unidades da Federação      99  Aérea        1  2024  Janeiro
# 3  Outras Unidades da Federação      99  Aérea        1  2024  Janeiro
# 4  Outras Unidades da Federação      99  Aérea        1  2024  Janeiro
#
#    cod mes  Chegadas
# 0        1        10
# 1        1      1197
# 2        1         3
# 3        1         2
# 4        1         1

# %%
arrivals_2015.isnull().sum(), arrivals_2016.isnull().sum(), arrivals_2017.isnull().sum(), arrivals_2018.isnull().sum(), arrivals_2019.isnull().sum(), arrivals_2020.isnull().sum(), arrivals_2021.isnull().sum(), arrivals_2022.isnull().sum(), arrivals_2023.isnull().sum(), arrivals_2024.isnull().sum()
# Out:
# (Continente             0
#  Ordem continente       0
#  País                   0
#  Ordem país             0
#  UF                     0
#  Ordem UF               0
#  Via de acesso          0
#  Ordem via de acesso    0
#  ano                    0
#  Mês                    0
#  Ordem mês              0
#  Chegadas               0
#  dtype: int64,
#  Continente        0
#  cod continente    0
#  País              0
#  cod pais          0
#  UF                0
#  cod uf            0
#  Via               0
#  cod via           0
#  ano               0
#  Mês               0
#  cod mes           0
#  Chegadas          0
#  dtype: int64,
#  Continente        0
#  cod continente    0
#  País              0
#  cod pais          0
#  UF                0
#  cod uf            0
#  Via               0
#  cod via           0
#  ano               0
#  Mês               0
#  cod mes           0
#  Chegadas          0
#  dtype: int64,
#  Continente        0
#  cod continente    0
# ...

# %%
arrivals_2015.dtypes, arrivals_2016.dtypes, arrivals_2017.dtypes, arrivals_2018.dtypes, arrivals_2019.dtypes, arrivals_2020.dtypes, arrivals_2021.dtypes, arrivals_2022.dtypes, arrivals_2023.dtypes, arrivals_2024.dtypes
# Out:
# (Continente               str
#  Ordem continente       int64
#  País                     str
#  Ordem país             int64
#  UF                       str
#  Ordem UF               int64
#  Via de acesso            str
#  Ordem via de acesso    int64
#  ano                    int64
#  Mês                      str
#  Ordem mês              int64
#  Chegadas               int64
#  dtype: object,
#  Continente          str
#  cod continente    int64
#  País                str
#  cod pais          int64
#  UF                  str
#  cod uf            int64
#  Via                 str
#  cod via           int64
#  ano               int64
#  Mês                 str
#  cod mes           int64
#  Chegadas          int64
#  dtype: object,
#  Continente          str
#  cod continente    int64
#  País                str
#  cod pais          int64
#  UF                  str
#  cod uf            int64
#  Via                 str
#  cod via           int64
#  ano               int64
# ...

# %% [markdown]
# # 03.2 Understanding the Our World in Data and UNWTO

# %%
international_tourism.shape, international_tourism_un.shape
# Out:
# ((5241, 4), (13900, 13))

# %%
# checking columns names - this is already groupped by country and year
international_tourism.head()
# Out:
#     Entity Code  Year  Arrivals of tourists from abroad
# 0  Albania  ALB  2007                         1062000.0
# 1  Albania  ALB  2008                         1247000.0
# 2  Albania  ALB  2009                         1711000.0
# 3  Albania  ALB  2010                         2191000.0
# 4  Albania  ALB  2011                         2469000.0

# %%
international_tourism.isna().sum()
# Out:
# Entity                               0
# Code                                48
# Year                                 0
# Arrivals of tourists from abroad     0
# dtype: int64

# %%
international_tourism.dtypes
# Out:
# Entity                                  str
# Code                                    str
# Year                                  int64
# Arrivals of tourists from abroad    float64
# dtype: object

# %%
# checking the possible raw data from UNWTO - preferential due to more granular data
international_tourism_un.head()
# Out:
#              indicator_code  \
# 0  INBD_TRIP_TOTL_CRUS_EXCR
# 1  INBD_TRIP_TOTL_CRUS_EXCR
# 2  INBD_TRIP_TOTL_CRUS_EXCR
# 3  INBD_TRIP_TOTL_CRUS_EXCR
# 4  INBD_TRIP_TOTL_CRUS_EXCR
#
#                                      indicator_label indicator_previous_code  \
# 0  inbound - trips - total - cruise ships - same-...                  CP_1_4
# 1  inbound - trips - total - cruise ships - same-...                  CP_1_4
# 2  inbound - trips - total - cruise ships - same-...                  CP_1_4
# 3  inbound - trips - total - cruise ships - same-...                  CP_1_4
# 4  inbound - trips - total - cruise ships - same-...                  CP_1_4
#
#    reporter_area_code reporter_area_label  partner_area_code  \
# 0                  16      American Samoa                999
# 1                  16      American Samoa                999
# 2                  16      American Samoa                999
# 3                  16      American Samoa                999
# ...

# %%
international_tourism_un.isna().sum()
# Out:
# indicator_code                 0
# indicator_label                0
# indicator_previous_code        0
# reporter_area_code             0
# reporter_area_label            0
# partner_area_code              0
# partner_area_label             0
# year                           0
# value                          0
# flag                       13740
# flag_label                 13740
# unit                           0
# notes                      13597
# dtype: int64

# %%
international_tourism_un.dtypes
# Out:
# indicator_code                 str
# indicator_label                str
# indicator_previous_code        str
# reporter_area_code           int64
# reporter_area_label            str
# partner_area_code            int64
# partner_area_label             str
# year                         int64
# value                      float64
# flag                           str
# flag_label                     str
# unit                           str
# notes                          str
# dtype: object
